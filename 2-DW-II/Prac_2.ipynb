# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/trushantramdasjadhav/Desktop/system/1-DW-I/StudentsPerformance.csv")

# %%
df1=pd.DataFrame(dict1)

# %%
df1.isnull()
# Out:
#    Roll_No   Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0    False  False        False          False          False          False
# 1    False  False        False          False          False           True
# 2    False  False        False          False           True          False
# 3    False  False        False           True          False          False
# 4    False  False         True          False          False          False
#
#    Geography_marks
# 0             True
# 1            False
# 2            False
# 3            False
# 4            False

# %%
df1.isnull().sum()
# Out:
# Roll_No            0
# Name               0
# Maths_marks        1
# English_marks      1
# Science_marks      1
# History_marks      1
# Geography_marks    1
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Roll_No          5 non-null      int64
#  1   Name             5 non-null      object
#  2   Maths_marks      4 non-null      float64
#  3   English_marks    4 non-null      float64
#  4   Science_marks    4 non-null      float64
#  5   History_marks    4 non-null      float64
#  6   Geography_marks  4 non-null      float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 412.0+ bytes

# %%
bool_series = pd.notnull(df1)
bool_series
# Out:
#    Roll_No  Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0     True  True         True           True           True           True
# 1     True  True         True           True           True          False
# 2     True  True         True           True          False           True
# 3     True  True         True          False           True           True
# 4     True  True        False           True           True           True
#
#    Geography_marks
# 0            False
# 1             True
# 2             True
# 3             True
# 4             True

# %%
# filling missing value using fillna()
df1.fillna(0,inplace=True)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           90.0
# 1        2   Dipak         70.0           80.0           90.0            0.0
# 2        3  Shreya         80.0           90.0            0.0           60.0
# 3        4  Krisha         90.0            0.0           60.0           70.0
# 4        5   Pooja          0.0           60.0           70.0           80.0
#
#    Geography_marks
# 0              0.0
# 1             60.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           90.0
# 1        2   Dipak         70.0           80.0           90.0            NaN
# 2        3  Shreya         80.0           90.0            NaN           60.0
# 3        4  Krisha         90.0            NaN           60.0           70.0
# 4        5   Pooja          NaN           60.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             60.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
# filling a missing value with
# previous ones
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,60],"Science_marks":[80,91,np.nan,60,70],"History_marks":[76,np.nan,60,70,80],"Geography_marks":[np.nan,60,70,80,90]}
df1=pd.DataFrame(dict1)

# %%
df1.fillna(method ='pad')
# Out:
# /tmp/ipykernel_8390/1848718746.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method ='pad')
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0           76.0
# 2        3  Shreya         80.0           40.0           91.0           60.0
# 3        4  Krisha         93.0           40.0           60.0           70.0
# 4        5   Pooja         93.0           60.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             60.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[np.nan,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
# filling a missing value with
# next ones
df1.fillna(method ='bfill')
# Out:
# /tmp/ipykernel_8390/3214477383.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method ='bfill')
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0           68.0
# 2        3  Shreya         80.0           40.0           65.0           68.0
# 3        4  Krisha         93.0           50.0           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0             62.0
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[np.nan,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
# filling a null values using fillna()
df1["Maths_marks"] = df1["Maths_marks"].fillna(45)
df1["English_marks"] = df1["English_marks"].fillna(55)
df1["Science_marks"] = df1["Science_marks"].fillna(65)
df1["History_marks"] = df1["History_marks"].fillna(75)
df1["Geography_marks"] = df1["Geography_marks"].fillna(85)

# %%
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0           75.0
# 2        3  Shreya         80.0           40.0           65.0           68.0
# 3        4  Krisha         93.0           55.0           65.0           70.0
# 4        5   Pooja         45.0           50.0           70.0           80.0
#
#    Geography_marks
# 0             85.0
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[np.nan,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
# filling a null values using fillna()
df1["Maths_marks"] = df1["Maths_marks"].fillna(int(df1["Maths_marks"].mean()))

# %%
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja         75.0           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[np.nan,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
# will replace  Nan value in dataframe with value 85
df1.replace(to_replace = np.nan, value = 85)
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0           85.0
# 2        3  Shreya         80.0           40.0           85.0           68.0
# 3        4  Krisha         93.0           85.0           65.0           70.0
# 4        5   Pooja         85.0           50.0           70.0           80.0
#
#    Geography_marks
# 0             85.0
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[np.nan,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
# to interpolate the missing values
df1.interpolate(method ='linear', limit_direction ='forward')
#c=(a+b)/2
# Out:
# /tmp/ipykernel_8390/1794567949.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df1.interpolate(method ='linear', limit_direction ='forward')
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0           72.0
# 2        3  Shreya         80.0           40.0           78.0           68.0
# 3        4  Krisha         93.0           45.0           65.0           70.0
# 4        5   Pooja         93.0           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,75],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[np.nan,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol           60           70.0           80.0           76.0
# 1        2   Dipak           70           80.0           91.0            NaN
# 2        3  Shreya           80           40.0            NaN           68.0
# 3        4  Krisha           93            NaN           65.0           70.0
# 4        5   Pooja           75           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
# using dropna() function
df1.dropna()
# Out:
#    Roll_No   Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 4        5  Pooja           75           50.0           70.0           80.0
#
#    Geography_marks
# 4             90.0

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[np.nan,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
# using dropna() function
df1.dropna(how = 'all',inplace=True)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           90.0
# 1        2   Dipak         70.0           80.0           90.0            NaN
# 2        3  Shreya         80.0           90.0            NaN           60.0
# 3        4  Krisha         90.0            NaN           60.0           70.0
# 4        5   Pooja          NaN           60.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             60.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[np.nan,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %%
# using dropna() function
df1.dropna(axis = 1)
# Out:
#    Roll_No    Name
# 0        1    Amol
# 1        2   Dipak
# 2        3  Shreya
# 3        4  Krisha
# 4        5   Pooja

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[60,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0               60
# 1               62
# 2               70
# 3               80
# 4               90

# %%
# making new data frame with dropped NA values
df2 = df1.dropna(axis = 0, how ='any')

# %%
df2
# Out:
#    Roll_No  Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1  Amol         60.0           70.0           80.0           76.0
#
#    Geography_marks
# 0               60

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,93,np.nan],"English_marks":[70,80,40,np.nan,50],"Science_marks":[80,91,np.nan,65,70],"History_marks":[76,np.nan,68,70,80],"Geography_marks":[np.nan,62,70,80,90]}
df1=pd.DataFrame(dict1)
df1
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0        1    Amol         60.0           70.0           80.0           76.0
# 1        2   Dipak         70.0           80.0           91.0            NaN
# 2        3  Shreya         80.0           40.0            NaN           68.0
# 3        4  Krisha         93.0            NaN           65.0           70.0
# 4        5   Pooja          NaN           50.0           70.0           80.0
#
#    Geography_marks
# 0              NaN
# 1             62.0
# 2             70.0
# 3             80.0
# 4             90.0

# %% [markdown]
# # OUTLIERS

# %%
# Importing
import sklearn
from sklearn.datasets import fetch_california_housing
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset (using California housing as an alternative)
housing = fetch_california_housing()

# Create the dataframe
column_name = housing.feature_names
df_boston = pd.DataFrame(housing.data)
df_boston.columns = column_name
df_boston.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %% [markdown]
# # 1. Visualization

# %%
# Box Plot
import seaborn as sns
sns.boxplot(df_boston['MedInc'])
# Out:
# <Axes: ylabel='MedInc'>

# %%
# Position of the Outlier
print(np.where(df_boston['MedInc']>10))
# Out:
# (array([  131,   409,   510,   511,   512,   514,   977,   986,  1563,
#         1564,  1566,  1582,  1583,  1586,  1591,  1593,  1602,  1617,
#         1621,  1636,  1637,  1644,  1645,  1646,  2213,  2826,  2969,
#         3486,  3533,  3858,  4014,  4018,  4042,  4044,  4045,  4046,
#         4047,  4049,  4050,  4056,  4070,  4074,  4111,  4116,  4220,
#         4229,  4319,  4345,  4352,  4492,  4604,  4605,  4606,  4622,
#         4626,  4677,  4678,  5242,  5243,  5244,  5247,  5248,  5250,
#         5252,  5253,  5254,  5256,  5257,  5258,  5259,  5260,  5264,
#         5269,  5271,  5272,  5275,  5277,  5281,  5291,  5292,  5304,
#         5318,  5352,  5360,  5361,  5368,  5494,  5728,  6073,  6204,
#         6391,  6399,  6551,  6590,  6591,  6592,  6712,  6720,  6724,
#         6725,  6726,  6727,  6728,  6731,  6735,  6736,  6915,  6919,
#         8311,  8768,  8790,  8792,  8793,  8794,  8795,  8796,  8797,
#         8799,  8805,  8806,  8816,  8817,  8846,  8847,  8848,  8849,
#         8850,  8851,  8852,  8853,  8854,  8875,  8876,  8878,  8882,
#         9011,  9136,  9316,  9354,  9356,  9370,  9381,  9382,  9418,
#         9794,  9811, 10155, 10317, 10318, 10332, 10376, 10401, 10402,
#        10405, 10417, 10458, 10464, 10483, 10484, 10517, 10519, 10527,
#        10562, 10644, 10661, 10667, 10670, 10671, 10673, 10682, 10724,
#        10726, 10727, 10742, 10743, 10744, 10745, 10749, 10757, 10759,
#        10760, 10763, 10999, 11000, 11007, 11008, 11010, 11020, 11037,
#        11038, 11041, 11469, 11490, 11520, 11521, 11704, 11828, 11912,
#        12430, 12948, 13742, 14459, 14467, 14469, 14482, 14486, 14491,
#        14686, 15152, 15230, 15231, 15232, 15233, 15235, 15241, 15691,
#        15693, 15694, 15697, 15698, 15996, 16011, 16019, 16020, 16137,
#        16171, 16175, 16304, 16828, 16908, 16909, 16910, 16911, 16912,
#        16913, 16914, 16915, 16918, 16938, 17107, 17108, 17109, 17110,
#        17111, 17113, 17118, 17158, 17160, 17161, 17162, 17166, 17167,
#        17170, 17171, 17173, 17310, 17798, 17854, 17855, 17858, 18043,
#        18052, 18053, 18055, 18059, 18061, 18065, 18066, 18067, 18069,
#        18078, 18079, 18080, 18081, 18087, 18269, 18280, 18281, 18282,
#        18283, 18287, 18298, 18325, 18327, 18341, 18347, 18348, 18351,
#        18352, 18353, 18354, 18355, 18356, 18360, 18361, 18362, 18363,
#        18366, 18501, 18504, 18619, 19006, 20163, 20376, 20380, 20389,
#        20426, 20436]),)

# %%
df_boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %% [markdown]
# # Using ScatterPlot

# %%
# Scatter plot
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df_boston['AveRooms'], df_boston['Population'])

# x-axis label
ax.set_xlabel('Average number of rooms')

# y-axis label
ax.set_ylabel('Population')
plt.show()

# %%
# Position of the Outlier
print(np.where((df_boston['AveRooms']>10) & (df_boston['Population']>20000)))
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# # 2. Z-score

# %%
# Z score
from scipy import stats
import numpy as np

z = np.abs(stats.zscore(df_boston['MedInc']))
print(z)
# Out:
# [2.34476576 2.33223796 1.7826994  ... 1.14259331 1.05458292 0.78012947]

# %%
threshold = 3

# Position of the outlier
print(np.where(z > 3))
# Out:
# (array([  131,   409,   510,   511,   512,   514,   923,   977,   986,
#         1541,  1561,  1563,  1564,  1566,  1574,  1582,  1583,  1586,
#         1591,  1593,  1602,  1617,  1621,  1636,  1637,  1644,  1645,
#         1646,  2213,  2826,  2969,  3486,  3533,  3542,  3858,  3953,
#         4014,  4018,  4042,  4044,  4045,  4046,  4047,  4049,  4050,
#         4056,  4070,  4074,  4111,  4116,  4220,  4229,  4319,  4345,
#         4352,  4492,  4604,  4605,  4606,  4622,  4626,  4677,  4678,
#         5242,  5243,  5244,  5246,  5247,  5248,  5250,  5252,  5253,
#         5254,  5256,  5257,  5258,  5259,  5260,  5264,  5269,  5271,
#         5272,  5275,  5277,  5281,  5291,  5292,  5304,  5318,  5352,
#         5360,  5361,  5368,  5493,  5494,  5728,  5738,  6073,  6204,
#         6226,  6389,  6391,  6399,  6551,  6576,  6590,  6591,  6592,
#         6712,  6720,  6724,  6725,  6726,  6727,  6728,  6731,  6732,
#         6735,  6736,  6915,  6919,  8311,  8768,  8790,  8792,  8793,
#         8794,  8795,  8796,  8797,  8799,  8800,  8805,  8806,  8809,
#         8814,  8816,  8817,  8846,  8847,  8848,  8849,  8850,  8851,
#         8852,  8853,  8854,  8875,  8876,  8878,  8882,  9010,  9011,
#         9136,  9316,  9354,  9356,  9370,  9381,  9382,  9418,  9794,
#         9811, 10155, 10166, 10169, 10317, 10318, 10324, 10332, 10376,
#        10389, 10401, 10402, 10405, 10417, 10458, 10464, 10472, 10483,
#        10484, 10517, 10519, 10527, 10562, 10644, 10661, 10667, 10670,
#        10671, 10673, 10682, 10724, 10725, 10726, 10727, 10742, 10743,
#        10744, 10745, 10749, 10757, 10759, 10760, 10761, 10763, 10839,
#        10999, 11000, 11007, 11008, 11010, 11020, 11037, 11038, 11041,
#        11042, 11469, 11490, 11518, 11519, 11520, 11521, 11704, 11828,
#        11912, 12430, 12948, 13742, 14459, 14467, 14469, 14482, 14486,
#        14491, 14686, 14718, 15152, 15230, 15231, 15232, 15233, 15235,
#        15241, 15691, 15693, 15694, 15697, 15698, 15996, 16011, 16019,
#        16020, 16137, 16171, 16175, 16304, 16828, 16908, 16909, 16910,
#        16911, 16912, 16913, 16914, 16915, 16918, 16938, 17106, 17107,
#        17108, 17109, 17110, 17111, 17112, 17113, 17118, 17157, 17158,
#        17160, 17161, 17162, 17166, 17167, 17170, 17171, 17173, 17310,
#        17493, 17494, 17798, 17854, 17855, 17858, 18043, 18052, 18053,
#        18055, 18059, 18061, 18065, 18066, 18067, 18069, 18076, 18078,
#        18079, 18080, 18081, 18087, 18269, 18277, 18280, 18281, 18282,
#        18283, 18287, 18298, 18325, 18327, 18341, 18347, 18348, 18351,
#        18352, 18353, 18354, 18355, 18356, 18360, 18361, 18362, 18363,
#        18366, 18501, 18504, 18505, 18619, 19006, 20163, 20376, 20380,
#        20389, 20426, 20436]),)

# %% [markdown]
# # 3. IQR (Inter Quartile Range)

# %%
import numpy as np
Q1 = np.percentile(df_boston['MedInc'], 25, method='midpoint')
Q3 = np.percentile(df_boston['MedInc'], 75, method='midpoint')

IQR = Q3 - Q1

# %%
# Above Upper bound
upper = df_boston['MedInc'] >= (Q3+1.5*IQR)

print("Upper bound:",upper)
print(np.where(upper))

# Below Lower bound
lower = df_boston['MedInc'] <= (Q1-1.5*IQR)
print("Lower bound:", lower)
print(np.where(lower))
# Out:
# Upper bound: 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 20635    False
# 20636    False
# 20637    False
# 20638    False
# 20639    False
# Name: MedInc, Length: 20640, dtype: bool
# (array([    0,     1,   131,   134,   135,   137,   154,   155,   407,
#          409,   494,   510,   511,   512,   513,   514,   516,   517,
#          888,   922,   923,   955,   977,   986,   996,  1541,  1554,
#         1556,  1561,  1563,  1564,  1566,  1574,  1578,  1580,  1582,
#         1583,  1585,  1586,  1587,  1589,  1590,  1591,  1593,  1594,
#         1599,  1602,  1617,  1621,  1626,  1628,  1629,  1636,  1637,
#         1638,  1639,  1644,  1645,  1646,  1647,  1653,  1654,  1655,
#         1659,  2213,  2214,  2215,  2226,  2227,  2826,  2969,  2971,
#         3472,  3476,  3481,  3485,  3486,  3487,  3529,  3533,  3534,
#         3535,  3542,  3556,  3557,  3561,  3571,  3572,  3575,  3858,
#         3952,  3953,  4002,  4014,  4015,  4018,  4039,  4042,  4044,
#         4045,  4046,  4047,  4048,  4049,  4050,  4056,  4067,  4070,
#         4071,  4072,  4074,  4075,  4077,  4106,  4108,  4111,  4116,
#         4220,  4229,  4233,  4244,  4319,  4345,  4346,  4350,  4352,
#         4353,  4354,  4492,  4603,  4604,  4605,  4606,  4622,  4626,
#         4653,  4677,  4678,  5241,  5242,  5243,  5244,  5246,  5247,
#         5248,  5250,  5252,  5253,  5254,  5255,  5256,  5257,  5258,
#         5259,  5260,  5261,  5264,  5265,  5266,  5267,  5269,  5271,
#         5272,  5273,  5275,  5277,  5279,  5280,  5281,  5291,  5292,
#         5295,  5304,  5305,  5318,  5351,  5352,  5353,  5355,  5360,
#         5361,  5367,  5368,  5420,  5493,  5494,  5537,  5723,  5724,
#         5728,  5730,  5738,  5932,  5935,  6072,  6073,  6204,  6226,
#         6374,  6389,  6390,  6391,  6392,  6395,  6399,  6551,  6556,
#         6557,  6576,  6577,  6578,  6584,  6585,  6590,  6591,  6592,
#         6593,  6594,  6691,  6710,  6712,  6720,  6724,  6725,  6726,
#         6727,  6728,  6729,  6730,  6731,  6732,  6735,  6736,  6785,
#         6911,  6915,  6918,  6919,  6977,  8311,  8572,  8578,  8585,
#         8586,  8628,  8632,  8759,  8768,  8786,  8787,  8788,  8790,
#         8791,  8792,  8793,  8794,  8795,  8796,  8797,  8798,  8799,
#         8800,  8803,  8804,  8805,  8806,  8809,  8814,  8815,  8816,
#         8817,  8846,  8847,  8848,  8849,  8850,  8851,  8852,  8853,
#         8854,  8869,  8874,  8875,  8876,  8877,  8878,  8879,  8882,
#         8900,  8987,  9004,  9010,  9011,  9013,  9026,  9028,  9030,
#         9031,  9033,  9136,  9158,  9299,  9310,  9316,  9352,  9354,
#         9355,  9356,  9361,  9370,  9380,  9381,  9382,  9386,  9399,
#         9401,  9418,  9755,  9794,  9811, 10148, 10149, 10154, 10155,
#        10166, 10169, 10292, 10298, 10311, 10312, 10317, 10318, 10319,
#        10324, 10328, 10332, 10333, 10335, 10339, 10343, 10372, 10376,
#        10377, 10388, 10389, 10393, 10401, 10402, 10405, 10417, 10458,
#        10464, 10472, 10481, 10483, 10484, 10490, 10517, 10519, 10520,
#        10527, 10536, 10537, 10544, 10551, 10553, 10562, 10564, 10568,
#        10576, 10612, 10614, 10618, 10626, 10640, 10644, 10661, 10666,
#        10667, 10668, 10670, 10671, 10673, 10681, 10682, 10720, 10723,
#        10724, 10725, 10726, 10727, 10728, 10742, 10743, 10744, 10745,
#        10748, 10749, 10757, 10759, 10760, 10761, 10763, 10796, 10828,
#        10829, 10839, 10968, 10999, 11000, 11001, 11005, 11007, 11008,
#        11009, 11010, 11018, 11020, 11021, 11037, 11038, 11039, 11040,
#        11041, 11042, 11383, 11469, 11490, 11497, 11515, 11517, 11518,
#        11519, 11520, 11521, 11606, 11608, 11627, 11641, 11697, 11702,
#        11704, 11746, 11828, 11898, 11901, 11912, 12196, 12430, 12543,
#        12691, 12732, 12733, 12736, 12822, 12948, 13177, 13229, 13236,
#        13242, 13243, 13742, 14007, 14008, 14459, 14465, 14467, 14468,
#        14469, 14473, 14481, 14482, 14483, 14484, 14486, 14491, 14557,
#        14686, 14687, 14717, 14718, 14803, 15037, 15152, 15153, 15194,
#        15230, 15231, 15232, 15233, 15235, 15241, 15390, 15542, 15543,
#        15617, 15691, 15692, 15693, 15694, 15697, 15698, 15996, 15997,
#        16011, 16012, 16019, 16020, 16135, 16137, 16171, 16175, 16304,
#        16828, 16893, 16908, 16909, 16910, 16911, 16912, 16913, 16914,
#        16915, 16917, 16918, 16938, 16940, 16990, 16995, 16999, 17021,
#        17023, 17045, 17106, 17107, 17108, 17109, 17110, 17111, 17112,
#        17113, 17118, 17138, 17145, 17146, 17147, 17153, 17156, 17157,
#        17158, 17159, 17160, 17161, 17162, 17163, 17165, 17166, 17167,
#        17170, 17171, 17173, 17183, 17234, 17289, 17294, 17295, 17310,
#        17493, 17494, 17717, 17798, 17839, 17854, 17855, 17858, 18038,
#        18042, 18043, 18046, 18051, 18052, 18053, 18055, 18056, 18058,
#        18059, 18060, 18061, 18065, 18066, 18067, 18068, 18069, 18071,
#        18073, 18076, 18077, 18078, 18079, 18080, 18081, 18083, 18085,
#        18086, 18087, 18088, 18106, 18129, 18155, 18177, 18269, 18270,
#        18273, 18274, 18277, 18278, 18280, 18281, 18282, 18283, 18285,
#        18286, 18287, 18291, 18296, 18297, 18298, 18323, 18325, 18327,
#        18330, 18340, 18341, 18347, 18348, 18351, 18352, 18353, 18354,
#        18355, 18356, 18357, 18358, 18360, 18361, 18362, 18363, 18364,
#        18366, 18376, 18377, 18378, 18380, 18381, 18384, 18387, 18388,
#        18389, 18501, 18504, 18505, 18619, 19006, 19412, 19865, 20163,
#        20335, 20367, 20375, 20376, 20377, 20380, 20382, 20389, 20421,
#        20426, 20427, 20428, 20436, 20503]),)
# Lower bound: 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20635    False
# 20636    False
# 20637    False
# 20638    False
# 20639    False
# Name: MedInc, Length: 20640, dtype: bool
# (array([], dtype=int64),)

# %% [markdown]
# # Removing the outliers

# %%
# Importing
import sklearn
from sklearn.datasets import fetch_california_housing
import pandas as pd
import numpy as np

# Load the dataset
housing = fetch_california_housing()

# Create the dataframe
column_name = housing.feature_names
df_boston = pd.DataFrame(housing.data)
df_boston.columns = column_name
df_boston.head()

''' Detection '''
# IQR
Q1 = np.percentile(df_boston['MedInc'], 25, method='midpoint')
Q3 = np.percentile(df_boston['MedInc'], 75, method='midpoint')
IQR = Q3 - Q1

print("Old Shape: ", df_boston.shape)

# Upper bound
upper = np.where(df_boston['MedInc'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(df_boston['MedInc'] <= (Q1-1.5*IQR))

''' Removing the Outliers '''
df_boston.drop(upper[0], inplace = True)
df_boston.drop(lower[0], inplace = True)

print("New Shape: ", df_boston.shape)
# Out:
# Old Shape:  (20640, 8)
# New Shape:  (19960, 8)

# %% [markdown]
# # data transformations

# %%
# importing pandas as pd
import pandas as pd

# Creating the DataFrame
df = pd.DataFrame({"A":[12, 4, 5, None, 1],
				"B":[7, 2, 54, 3, None],
				"C":[20, 16, 11, 3, 8],
				"D":[14, 3, None, 2, 6]})

# Create the index
index_ = ['Row_1', 'Row_2', 'Row_3', 'Row_4', 'Row_5']

# Set the index
df.index = index_

# Print the DataFrame
print(df)

# %%
# pass a list of functions
result = df_boston.transform(func=['sqrt', 'exp'])
print(result)
# Print the result
#print(result)
# Out:
#          MedInc               HouseAge                AveRooms               \
#            sqrt          exp      sqrt           exp      sqrt          exp
# 2      2.693956  1418.563473  7.211103  3.831008e+22  2.878912  3976.413627
# 3      2.375521   282.336607  7.211103  3.831008e+22  2.411919   336.080797
# 4      1.961173    46.814828  7.211103  3.831008e+22  2.506363   534.778842
# 5      2.009179    56.644789  7.211103  3.831008e+22  2.182122   116.939655
# 6      1.912877    38.826383  7.211103  3.831008e+22  2.220790   138.643600
# ...         ...          ...       ...           ...       ...          ...
# 20635  1.249120     4.760249  5.000000  7.200490e+10  2.246209   155.314881
# 20636  1.599000    12.894489  4.242641  6.565997e+07  2.472657   452.159543
# 20637  1.303840     5.473947  4.123106  2.415495e+07  2.281566   182.279774
# 20638  1.366455     6.470155  4.242641  6.565997e+07  2.308574   206.337441
# 20639  1.545510    10.898226  4.000000  8.886111e+06  2.292317   191.467289
#
#       AveBedrms           Population                 AveOccup             \
#            sqrt       exp       sqrt            exp      sqrt        exp
# 2      1.036073  2.925444  22.271057  2.570769e+215  1.673995  16.481852
# 3      1.035886  2.924312  23.622024  2.169306e+242  1.596228  12.780815
# 4      1.039750  2.947865  23.769729  2.378933e+245  1.476979   8.859295
# 5      1.050537  3.015082  20.322401  2.310048e+179  1.462838   8.498557
# 6      0.975378  2.589233  33.075671            inf  1.458905   8.401453
# ...         ...       ...        ...            ...       ...        ...
# 20635  1.064581  3.105993  29.068884            inf  1.600189  12.943660
# 20636  1.147079  3.727693  18.867962  4.062895e+154  1.767147  22.710038
# 20637  1.058344  3.065137  31.733263            inf  1.525003  10.233177
# 20638  1.082552  3.228184  27.221315            inf  1.457124   8.357916
# 20639  1.078084  3.197164  37.242449            inf  1.617709  13.694320
#
#        Latitude               Longitude
#            sqrt           exp      sqrt           exp
# 2      6.152235  2.741865e+16       NaN  8.162863e-54
# 3      6.152235  2.741865e+16       NaN  8.081642e-54
# 4      6.152235  2.741865e+16       NaN  8.081642e-54
# 5      6.152235  2.741865e+16       NaN  8.081642e-54
# 6      6.151423  2.714583e+16       NaN  8.081642e-54
# ...         ...           ...       ...           ...
# 20635  6.283311  1.399414e+17       NaN  2.577990e-53
# 20636  6.284107  1.413478e+17       NaN  2.286472e-53
# 20637  6.279331  1.331164e+17       NaN  2.263721e-53
# 20638  6.279331  1.331164e+17       NaN  2.048299e-53
# 20639  6.274552  1.253643e+17       NaN  2.218896e-53
#
# [19960 rows x 16 columns]
# /Users/trushantramdasjadhav/Desktop/system/venv/lib/python3.14/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/trushantramdasjadhav/Desktop/system/venv/lib/python3.14/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# # SCALING

# %% [markdown]
# # Method 1: Using Pandas and Numpy

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/trushantramdasjadhav/Desktop/system/venv/lib/python3.14/site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in /Users/trushantramdasjadhav/Desktop/system/venv/lib/python3.14/site-packages (from seaborn) (3.0.2)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Downloading matplotlib-3.10.9-cp314-cp314-macosx_11_0_arm64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading fonttools-4.62.1-cp314-cp314-macosx_10_15_universal2.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading kiwisolver-1.5.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/trushantramdasjadhav/Desktop/system/venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached pillow-12.2.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/trushantramdasjadhav/Desktop/system/venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/trushantramdasjadhav/Desktop/system/venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading matplotlib-3.10.9-cp314-cp314-macosx_11_0_arm64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 1.9 MB/s  0:00:041.9 MB/s eta 0:00:01:020m
# Downloading contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl (273 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp314-cp314-macosx_10_15_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 5.0 MB/s  0:00:004.9 MB/s eta 0:00:01:01
# Downloading kiwisolver-1.5.0-cp314-cp314-macosx_11_0_arm64.whl (64 kB)
# Using cached pillow-12.2.0-cp314-cp314-macosx_11_0_arm64.whl (4.7 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [seaborn]━━━ 7/8 [seaborn]ib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.9 pillow-12.2.0 pyparsing-3.3.2 seaborn-0.13.2
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import pandas as pd
import numpy as np

data = sns.load_dataset('iris')
print('Original Dataset')
data.head()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Original Dataset
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Min-Max Normalization
df = data.drop('species', axis=1)
df_norm = (df-df.min())/(df.max()-df.min())
df_norm = pd.concat((df_norm, data.species))

print("Scaled Dataset Using Pandas")
df_norm.head()
# Out:
# Scaled Dataset Using Pandas
#    sepal_length  sepal_width  petal_length  petal_width species
# 0      0.222222     0.625000      0.067797     0.041667     NaN
# 1      0.166667     0.416667      0.067797     0.041667     NaN
# 2      0.111111     0.500000      0.050847     0.041667     NaN
# 3      0.083333     0.458333      0.084746     0.041667     NaN
# 4      0.194444     0.666667      0.067797     0.041667     NaN

# %%
# skewness along the index axis
df_norm.skew(axis = 0, skipna = True, numeric_only=True)
# Out:
# sepal_length    0.314911
# sepal_width     0.318966
# petal_length   -0.274884
# petal_width    -0.102967
# dtype: float64

# %%
# find skewness in each row
df.skew(axis = 1, skipna = True)
# Out:
# 0      0.189328
# 1      0.404389
# 2      0.208782
# 3      0.120130
# 4      0.090753
#          ...
# 145    0.351514
# 146    0.256478
# 147    0.134795
# 148   -0.146244
# 149   -0.185387
# Length: 150, dtype: float64

# %% [markdown]
# For a unimodal distribution, negative skew commonly indicates that the tail is on the left side of the distribution, and positive skew indicates that the tail is on the right. In cases where one tail is long but the other tail is fat, skewness does not obey a simple rule. For example, a zero value means that the tails on both sides of the mean balance out overall; this is the case for a symmetric distribution, but can also be true for an asymmetric distribution where one tail is long and thin, and the other is short but fat.

# %% [markdown]
# # Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics



# Calculating mean and standard deviation
mean = statistics.mean(df_norm["sepal_length"])
sd = df_norm["sepal_length"].std()

plt.plot(df_norm["sepal_length"], norm.pdf(df_norm["sepal_length"], mean, sd))
plt.show()

# %%
# Calculating mean and standard deviation
mean = statistics.mean(df_norm["petal_width"])
sd = df_norm["sepal_length"].std()

plt.plot(df_norm["petal_width"], norm.pdf(df_norm["petal_width"], mean, sd))
plt.show()

# %%
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

data = sns.load_dataset('iris')
print('Original Dataset')
data.head()

scaler = MinMaxScaler()

df_scaled = scaler.fit_transform(df.to_numpy())
df_scaled = pd.DataFrame(df_scaled, columns=[
'sepal_length', 'sepal_width', 'petal_length', 'petal_width'])

print("Scaled Dataset Using MinMaxScaler")
df_scaled.head()
# Out:
# Original Dataset
# Scaled Dataset Using MinMaxScaler
#    sepal_length  sepal_width  petal_length  petal_width
# 0      0.222222     0.625000      0.067797     0.041667
# 1      0.166667     0.416667      0.067797     0.041667
# 2      0.111111     0.500000      0.050847     0.041667
# 3      0.083333     0.458333      0.084746     0.041667
# 4      0.194444     0.666667      0.067797     0.041667

# %%
# Calculating mean and standard deviation
mean = statistics.mean(df_scaled["sepal_length"])
sd = statistics.stdev(df_scaled["sepal_length"])

plt.plot(df_scaled["sepal_length"], norm.pdf(df_scaled["sepal_length"], mean, sd))
plt.show()

# %% [markdown]
# # Standardization

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import seaborn as sns

data = sns.load_dataset('iris')
print('Original Dataset')
data.head()
# Out:
# Original Dataset
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.drop(["species"],inplace=True,axis=1)

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
std_scaler = StandardScaler()

df_scaled = std_scaler.fit_transform(data.to_numpy())
df_scaled = pd.DataFrame(df_scaled, columns=[
'sepal_length','sepal_width','petal_length','petal_width'])

print("Scaled Dataset Using StandardScaler")
df_scaled.head()
# Out:
# Scaled Dataset Using StandardScaler
#    sepal_length  sepal_width  petal_length  petal_width
# 0     -0.900681     1.019004     -1.340227    -1.315444
# 1     -1.143017    -0.131979     -1.340227    -1.315444
# 2     -1.385353     0.328414     -1.397064    -1.315444
# 3     -1.506521     0.098217     -1.283389    -1.315444
# 4     -1.021849     1.249201     -1.340227    -1.315444

# %% [markdown]
# Standardization doesn’t have any fixed minimum or maximum value. Here, the values of all the columns are scaled in such a way that they all have a mean equal to 0 and standard deviation equal to 1. This scaling technique works well with outliers. Thus, this technique is preferred if outliers are present in the dataset.
